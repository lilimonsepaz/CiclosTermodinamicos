# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x1 = 1 ; x2 = 2 ; xC = x1,x2 ; yC = y1,y2 ; y1 = 107.4131 ; y2 = 91.5513 ; Condensador = [ xC,yC]
y3 = 56.9521 ; y4 = 74.3367 ; yCa = y3,y4 ;  Caldera = [ xC,yCa]
y5 = 15.5904 ; y6 = 32.7748 ; yT = y5,y6 ; Turbina = [ xC,yT]
y7 = 0.0437 ; y8 = 0.0469 ; yB = y7,y8 ; Bomba = [ xC,yB]
fig,ax = plt.subplots(1,figsize=(10,10))
plt.plot(xC,yC,xC,yCa,xC,yT,xC,yB,marker='o',markersize=5)
componentes = ('Condensador','Caldera','Turbina','Bombas');
plt.legend(componentes,loc='upper left', frameon=False)
plt.xlim(0.7,2.2)
plt.xticks([])
# Out:
# ([], [])

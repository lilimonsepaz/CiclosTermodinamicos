# %%
from tabulate import tabulate
from skimage import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyXSteam.XSteam import XSteam
steamTable = XSteam(XSteam.UNIT_SYSTEM_MKS)

# %%
T1 = 250 #ºC
P1 = 6.5 #bar
H_P1 = (steamTable.hL_t(T1))
P2 = P1
P3 = P2
P4 = P3
P7 = P2
Flujo_mas1 = 420 #kg/s
Fm_P2 =Flujo_mas1
P5 = 0.115 #bar
nsf = 0.85
Ho = 317.17
So = 1.4088
Po = 101.325*0.01
To = 293
T_cool=25
T_cout=30
c1 = 1.3
c2=1.3
c3=c2
c4=c3
c5=c4
c6=c5
c7=c6
c8=c7
c9=1.31
c10=c9
i=0.14
n=20
mantto=1.06
h=7000

# %%
T1 = 250 #ºC
H_P1 = (steamTable.hL_t(T1))
p5 = 0.115,0.12,0.125
p1 = 6.5,7,7.5
P2 = p1
P3 = P2
P4 = P3
P7 = P2

x2 = []
HP3 = []
S_P3 = []
T_P3 = []
Fm_P3 = []
Ex3 = []
H_P3 = []
h = []

#Punto 3
for P3 in p1:
    S_P3.append(steamTable.sL_p(P3))
    x2.append(steamTable.x_ph(P3,H_P1))
    HP3.append(steamTable.hL_p(P3))
    h.append(HP3)
    for H_P3 in HP3:
        HP3 = []
        T_P3.append((steamTable.t_ph(P3,H_P3)))    
for x_2 in x2:
    Fm_P3.append(420*(1-x_2))

#Punto 4

    
h,S_P3,x2,Fm_P3,T_P3
# Out:
# ([[684.2156015748093], [697.1433607352077], [709.3837576737136]],
#  [1.9626009801624904, 1.9920831368489642, 2.0198074325110937],
#  [0.19344472842848134, 0.1881014599253821, 0.18300389898132302],
#  [338.7532140600378, 340.99738683133955, 343.13836242784436],
#  [162.00984303515168, 164.9760902410863, 167.7783617456821])

# %%
h = np.array(h)
h
# Out:
# array([[684.21560157],
#        [697.14336074],
#        [709.38375767]])

# %%
#Prueba 11 agosto

# %%
T1 = 250 #ºC
H_P1 = (steamTable.hL_t(T1))
H_P2 = H_P1

p5 = 0.115,0.12,0.125
p1 = 6.5,7,7.5
P2 = p1
P3 = P2
P4 = P3
P7 = P2

x2 = []
HP3 = []
S_P3 = []
T_P3 = []
Fm_P3 = []
Ex3 = []
H_P3 = []
h3 = []
H_P4 = []
h4 = []
S_P4 = []
T_P4 = []
Fm_P4 = []
S_P2 = []
sp5s = []
H_P5s = []
H_P5R = []
WITurbina = []

#Punto 3
for P3 in p1:
    S_P3.append(steamTable.sL_p(P3))
    x2.append(steamTable.x_ph(P3,H_P1))
#Entropía punto 2    
    S_P2.append(steamTable.s_ph(P3,H_P2))
    HP3.append(steamTable.hL_p(P3))
    h3.append(HP3)
#Punto 4 
    H_P4.append(steamTable.hV_p(P3))
    h4.append(H_P4)
    S_P4.append(steamTable.sV_p(P3))
    sp5s=S_P4
    for H_P3 in HP3:
        HP3 = []
        T_P3.append((steamTable.t_ph(P3,H_P3)))
        for HP4 in H_P4:
            H_P4 = []
            T_P4.append(steamTable.t_ph(P3,HP4))
            T_P2 = T_P4
            H_P2 = H_P1
for x_2 in x2:
    Fm_P3.append(420*(1-x_2))
    Fm_P4.append(420 * x_2)
    Fm_P5 = Fm_P4
for P5 in p5:
    for S_P5s in sp5s:
        sp5s = []
        H_P5s.append((steamTable.h_ps(P5,S_P5s)))

# WITurbina = H_P4 - H_P5s       

    
x2,Fm_P3,Fm_P4,h3,h4,H_P2,H_P5s,Fm_P5
# Out:
# ([0.19344472842848134, 0.1881014599253821, 0.18300389898132302],
#  [338.7532140600378, 340.99738683133955, 343.13836242784436],
#  [81.24678593996217, 79.00261316866049, 76.86163757215567],
#  [[684.2156015748093], [697.1433607352077], [709.3837576737136]],
#  [[2759.5950361387345], [2762.74908276951], [2765.6407942780215]],
#  1085.686812680083,
#  [2148.737227295003, 2140.655701280793, 2133.1120946084843],
#  [81.24678593996217, 79.00261316866049, 76.86163757215567])

# %%
h4 = np.array(h4)
H_P5s = np.array(H_P5s)
h4
# Out:
# array([[2759.59503614],
#        [2762.74908277],
#        [2765.64079428]])

# %%
T1 = 250 #ºC
H_P1 = (steamTable.hL_t(T1))
p5 = 0.115,0.12,0.125
p1 = 6.5,7,7.5
P2 = p1
P3 = P2
P4 = P3
P7 = P2

x2 = []
HP3 = []
SP3 = []
T_P3 = []
Fm_P3 = []
Ex3 = []
H_P3 = []
h3 = []
s3 = []
fm3 = []
x22 = []

#Punto 3
for P3 in p1:
    SP3.append(steamTable.sL_p(P3))
    x22.append(steamTable.x_ph(P3,H_P1))
    HP3.append(steamTable.hL_p(P3))
    h3.append(HP3)
    s3.append(S_P3)
    x2.append(x22)   
    for H_P3 in HP3:
        HP3 = []
        T_P3.append((steamTable.t_ph(P3,H_P3))) 
for x_2 in x22:
    x22 = []
    Fm_P3.append(420*(1-x_2))
    fm3.append(Fm_P3)
    
    
    
    
#            for S_P3 in SP3:
#                SP3 = []
#                Fm_P3 = []
#          Ex3=(Fm_P3*((H_P3-Ho)-To*(S_P3-So)))
    
h3,s3,x2,fm3
# Out:
# ([[684.2156015748093], [697.1433607352077], [709.3837576737136]],
#  [[1.9626009801624904, 1.9920831368489642, 2.0198074325110937],
#   [1.9626009801624904, 1.9920831368489642, 2.0198074325110937],
#   [1.9626009801624904, 1.9920831368489642, 2.0198074325110937]],
#  [[0.19344472842848134, 0.1881014599253821, 0.18300389898132302],
#   [0.19344472842848134, 0.1881014599253821, 0.18300389898132302],
#   [0.19344472842848134, 0.1881014599253821, 0.18300389898132302]],
#  [[338.7532140600378, 340.99738683133955, 343.13836242784436],
#   [338.7532140600378, 340.99738683133955, 343.13836242784436],
#   [338.7532140600378, 340.99738683133955, 343.13836242784436]])

# %%
#T_P3 = (list((steamTable.t_ph(P3,H_P3)) for H_P3 in HP3))

for x_2 in x2:
    Fm_P3.append(420*(1-x_2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7c/mp3x_xn118g6zt9pk4_pn36w0000gn/T/ipykernel_23810/4132502536.py in <module>
#       2
#       3 for x_2 in x2:
# ----> 4     Fm_P3.append(420*(1-x_2))
#
# TypeError: unsupported operand type(s) for -: 'int' and 'list'

# %%
SP31=(steamTable.sL_p(6.5))
SP32=(steamTable.sL_p(7))
SP33=(steamTable.sL_p(7.5))
x21=(steamTable.x_ph(6.5,H_P1))
x22=(steamTable.x_ph(7,H_P1))
x23=(steamTable.x_ph(7.5,H_P1))
Fm_P31 = (420*(1-x21))
Fm_P32 = (420*(1-x22))
Fm_P33 = (420*(1-x23))
HP31 = (steamTable.hL_p(6.5))
HP32 = (steamTable.hL_p(7))
HP33 = (steamTable.hL_p(7.5))
TP31 = (steamTable.t_ph(6.5,HP31))
TP32 = (steamTable.t_ph(7,HP32))
TP33 = (steamTable.t_ph(7.5,HP33))
Ex31 = Fm_P31*((HP31-Ho)-To*(SP31-So))
Ex32 = Fm_P32*((HP32-Ho)-To*(SP32-So))
Ex33 = Fm_P33*((HP33-Ho)-To*(SP33-So))
Ex31,Ex32,Ex33

# %%
T_P3 = (steamTable.t_ph(P3,H_P3))
Fm_P3 = 420 * (1-x2)
Ex3 = Fm_P3*((H_P3-Ho)-To*(S_P3-So))
C3 = (c3*Ex3)/1000000

# %%
     #Punto 4 
        H_P4 = (steamTable.hV_p(P4))
        S_P4 = (steamTable.sV_p(P4))
        T_P4 = (steamTable.t_ph(P4,H_P4))
        Fm_P4 = 420 * x2
        Ex4 = Fm_P4*((H_P4-Ho)-To*(S_P4-So))
        C4 = (c4*Ex4)/1000000

        #Punto 2
        T_P2 = T_P4
        H_P2 = H_P1
        S_P2 = (steamTable.s_ph(P2,H_P2))
        Ex2 = Flujo_mas1*((H_P2-Ho)-To*(S_P2-So))
        C2 = (c2*Ex2)/1000000

        #Punto 5
        S_P5s = S_P4
        H_P5s = (steamTable.h_ps(P5,S_P5s))
        WITurbina = H_P4 - H_P5s
        H_P5R = H_P4 - (nsf*WITurbina)
        S_P5R = (steamTable.s_ph(P5,H_P5R))
        T_P5 = (steamTable.t_ps(P5,S_P5R))
        Fm_P5 = Fm_P4
        Ex5 = Fm_P5*((H_P5R-Ho)-To*(S_P5R-So))
        C5 = (c5*Ex5)/1000000


        #Punto 6
        T_P6 = T_P5
        P6 = P5
        H_P6 = (steamTable.hL_p(P5))
        S_P6 = (steamTable.sL_t(T_P5))
        v6 = (steamTable.v_ph(P6,H_P6))
        Fm_P6 = Fm_P5
        Ex6 = Fm_P6*((H_P6-Ho)-To*(S_P6-So))
        C6 = (c6*Ex6)/1000000

        #Punto 7
        T_P7 = T_P5
        H_P7 = (steamTable.h_pt(P7,T_P5))
        S_P7 = (steamTable.sL_t(T_P7))
        Fm_P7 = Fm_P6
        Ex7 = Fm_P7*((H_P7-Ho)-To*(S_P7-So))
        C7 = (c7*Ex7)/1000000

        #Punto 8
        P8 = P2
        Fm_P8 = Fm_P7+Fm_P3
        H_P8 = ((Fm_P3*H_P3)+(Fm_P7*H_P7))/Fm_P8
        S_P8 = (steamTable.s_ph(P8,H_P8))
        T_P8 = (steamTable.t_ph(P8,H_P8))
        Ex8 = Fm_P8*((H_P8-Ho)-To*(S_P8-So))
        C8 = (c8*Ex8)/1000000

        #Punto 9 entrada torre de enfriamiento
        T_P9 = T_cool
        P9 = Po
        H_P9 = (steamTable.h_pt(Po,T_P9))
        S_P9 = (steamTable.s_pt(Po,T_P9))


        #Punto 10 salida torre de enfriamiento
        T_P10 = T_cout
        P10 = Po
        H_P10 = (steamTable.h_pt(Po,T_P10))
        S_P10 = (steamTable.s_pt(Po,T_P10))

        #Flujo en el condensador
        Q_condensador = (H_P5R - H_P6)*(Fm_P6)
        fm9 = Q_condensador/(H_P10-H_P9)
        Fm_P9 = fm9
        Fm_P10 = Fm_P9
        Ex9 = Fm_P9*((H_P9-Ho)-To*(S_P9-So))
        C9 = (c9*Ex9)/1000000
        Ex10 = Fm_P10*((H_P10-Ho)-To*(S_P10-So))
        C10 = (c10*Ex10)/1000000

        #Datos por puntos
        Pt2 =  T_P2,P2,H_P2,S_P2,Fm_P2,Ex2,C2,c2
        Pt3 =  T_P3,P3,H_P3,S_P3,Fm_P3,Ex3,C3,c3
        Pt4 =  T_P4,P4,H_P4,S_P4,Fm_P4,Ex4,C4,c4
        Pt5 =  T_P5,P5,H_P5R,S_P5R,Fm_P5,Ex5,C5,c5
        Pt6 =  T_P6,P6,H_P6,S_P6,Fm_P6,Ex6,C6,c6
        Pt7 =  T_P7,P7,H_P7,S_P7,Fm_P7,Ex7,C7,c7
        Pt8 =  T_P8,P8,H_P8,S_P8,Fm_P8,Ex8,C8,c8
        Pt9 =  T_P9,P9,H_P9,S_P9,Fm_P9,Ex9,C9,c9
        Pt10 =  T_P10,P10,H_P10,S_P10,Fm_P10,Ex10,C10,c10


        #Potencia de salida del sistema
        W_bomba = v6 * (P7 - P6)*10000
        W_turbina = ( H_P4 - H_P5R)*(Fm_P6)
        Wtotal = W_turbina - W_bomba

        #Eficiencias
        Primera = Wtotal/(H_P2*(250-30))
        Segunda = Wtotal / Ex2

        #Resultados potencias y eficiencias
        R = [W_bomba, W_turbina, Wtotal, Q_condensador,Primera,Segunda]
        columnas = ['Resultados']
        filas = ['Bomba [kW]','Turbina [kW]','Potencia total [kW]','Flujo en el condensador [kW]','Eficiencia 1ra Ley','Eficiencia 2da Ley']
        df2 = pd.DataFrame(R,columns = columnas, index = filas)

        #Resultados termodinámicos
        Resultados = [Pt2, Pt3, Pt4, Pt5,Pt6,Pt7,Pt8,Pt9,Pt10]
        columnas = ['T [ºC]','P [bar]','h [kJ/kg]','s[kJ/kgK]','Flujo másico [kg/s]','Exergías [kW]','$^\dot C$[$/s]','c[$/GJ]']
        filas = [2,3,4,5,6,7,8,9,10]
        df = pd.DataFrame(Resultados,columns = columnas, index = filas)

        #Irreversibilidades
        DexC = (Ex5+Ex9)-(Ex6+Ex10)
        DexT = (Fm_P4*To)*(S_P5R-S_P4)
        DexM = (Ex3+Ex7)-(Ex8)
        DexS = Ex2-(Ex4+Ex3)
        DexB = (Fm_P6*To)*(S_P7-S_P6)
        DexV = 0
        DexTot= DexC+DexT+DexM+DexS+DexB
        Dex = DexC,DexT,DexM,DexTot

        #Resultados de irreversibilidades
        row1 = [DexB,DexT,DexS,DexC,DexM]
        row_2 = ['Bomba, $<1 \%$','Turbina, $32.5\%$','Separador,$<1\%$','Condensador, $50.7\%$','Mezclador, $16.7\%$']
        k = ['Destrucción exergética']
        df_tec = pd.DataFrame(row1,columns=k,index=row_2)
